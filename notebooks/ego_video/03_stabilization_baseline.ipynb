# %% [markdown]
# # 03 Stabilization Baseline
#
# Use the global-motion estimate to smooth the camera path and export a stabilized clip.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().resolve()
if repo_root.name == "ego_video":
    repo_root = repo_root.parents[1]
elif repo_root.name == "notebooks":
    repo_root = repo_root.parent
src_root = repo_root / "src"
if str(src_root) not in sys.path:
    sys.path.insert(0, str(src_root))

from vibelab.ego_video.motion.stabilize import stabilize_video

# %%
clip_path = Path("/data/datasets/ego_video/builddotai/ego10k_clips/eval_clip.mp4")
stabilized_path = Path("/data/datasets/ego_video/builddotai/ego10k_clips/eval_clip_stabilized.mp4")
clip_path, stabilized_path

# %% [markdown]
# ## TODO
#
# - Run stabilization on the chosen clip
# - Compare raw and stabilized outputs visually
# - Save notes on failure cases such as rotations or moving foreground
